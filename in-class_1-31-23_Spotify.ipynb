# %%
import pandas as pd
import json

# %%
file_path = "Spotify_Montero_data.json"
file_path = 'Spotify_Montero_data.json'
with open(file_path) as s:
    mess = json.load(s)

# %%
type(mess)
# Out:
# dict

# %%
mess.keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
mess['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#   'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#   'id': '7jVv8c5Fj3E9VhNjxT4snq',
#   'name': 'Lil Nas X',
#   'type': 'artist',
#   'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}]

# %%
type(mess['artists'])
# Out:
# list

# %%
len(mess['artists'])
# Out:
# 1

# %%
mess['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#  'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#  'id': '7jVv8c5Fj3E9VhNjxT4snq',
#  'name': 'Lil Nas X',
#  'type': 'artist',
#  'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}

# %%
type(mess['artists'][0])
# Out:
# dict

# %%
mess['artists'][0].keys()
# Out:
# dict_keys(['external_urls', 'href', 'id', 'name', 'type', 'uri'])

# %%
mess['artists'][0]['id']
# Out:
# '7jVv8c5Fj3E9VhNjxT4snq'

# %%
album_df = pd.DataFrame(mess['artists'])
album_df
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/7...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/7jVv8c5Fj3E...  7jVv8c5Fj3E9VhNjxT4snq
#
#         name    type                                    uri
# 0  Lil Nas X  artist  spotify:artist:7jVv8c5Fj3E9VhNjxT4snq

# %%
tracks_df = pd.DataFrame(mess['tracks'])

# %%
tracks_df
# Out:
#                                                  href  \
# 0   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 1   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 2   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 3   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 4   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 5   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 6   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 7   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 8   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 9   https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 10  https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 11  https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 12  https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 13  https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
# 14  https://api.spotify.com/v1/albums/6pOiDiuDQqrm...
#
#                                                 items  limit  next  offset  \
# ...

# %%
type(mess['tracks']['items'])
# Out:
# list

# %%
len(mess['tracks']['items'])
# Out:
# 15

# %%
mess['tracks']['items'][0].keys()
# Out:
# dict_keys(['artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_urls', 'href', 'id', 'is_local', 'name', 'preview_url', 'track_number', 'type', 'uri'])

# %%
tracks_df = pd.DataFrame(mess['tracks']['items'])

# %%
tracks_df
# Out:
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# ...

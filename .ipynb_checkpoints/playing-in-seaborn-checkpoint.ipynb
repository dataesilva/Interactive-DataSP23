# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats

# %%
dat = pd.read_csv('cces_example_data.csv')

# %%
dat.columns
# Out:
# Index(['pew_religimp', 'pew_churatd', 'sex', 'educ', 'nonwhite', 'age',
#        'faminc_new', 'pid3', 'ideo5', 'QueerPhobia', 'ImmiPhobia',
#        'InterGBiasParty', 'InterGBiasCand', 'InterGBiasSup', 'LibMediaUse',
#        'ConMediaUse', 'Real_Threat', 'Symb_Threat', 'Evaluation', 'teamweight',
#        'caseid'],
#       dtype='object')

# %%
dat[dat['pid3'] != 3].head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
age_by_libmedia = sns.relplot(data=dat, x = 'age', y = 'LibMediaUse', hue = 'pid3')
sns.move_legend(age_by_libmedia, 'upper right')

# %%
age_by_libmedia = sns.relplot(data=dat[dat['pid3'] != 3], x = 'age', y = 'LibMediaUse', hue = 'pid3', palette = 'Set2', alpha = 0.9)
sns.move_legend(age_by_libmedia, 'upper right')

# %%
violin1 = sns.violinplot(data = dat, x = 'pid3', y = 'faminc_new')

# %%
stats.describe(dat['faminc_new'])
# Out:
# DescribeResult(nobs=659, minmax=(1, 97), mean=15.90895295902883, variance=768.6482327926167, skewness=2.539853218670569, kurtosis=4.595839558162238)

# %%
hist = sns.histplot(data = dat, x = 'faminc_new')

# %%
dat['pid3_labeled'] = dat['pid3'].replace([1, 2, 3], ['Dem', 'Rep', 'Ind'])

# %%
violin2 = sns.violinplot(data = dat[dat['faminc_new'] != 97],
                         x = 'pid3_labeled',
                         y = 'faminc_new',
                         cut = 0,
                        )
